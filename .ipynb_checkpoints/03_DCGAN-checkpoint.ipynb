# %% [markdown]
# # 03 - Implementation of Deep Convolutional GAN (DCGAN)
#
#
#     Deep Convolutional GAN from "https://arxiv.org/pdf/1511.06434.pdf%5D" (2016, A. Radford et. al.)
#
#     Kernel-author: Jackson Kang @ Deep-learning Lab. (Handong Global University, S.Korea)
#
#     Author-email:  mskang@handong.edu
#
#     python and pytorch version: python=3.7, pytorch=1.6

# %%
import torch
import torch.nn as nn
from torch.optim import Adam

import numpy as np
from tqdm import tqdm

from torchvision.utils import save_image, make_grid
from torchvision.datasets import CelebA
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Step 00. Hyperparameter Setting

# %%
# Dataset Info.
dataset_path = '~/datasets'
kwargs = {'num_workers': 1, 'pin_memory': True} 
noise_dim=100
sample_dim = 3
image_size = 64

# CUDA and GPU Info.
cuda = True
DEVICE = torch.device("cuda" if cuda else "cpu")

# Training info.
batch_size = 64
test_batch_size = 64
gen_lr = 0.0002
disc_lr = 0.0002
epochs = 5
generator_train_step = 1
discriminator_train_step = 1

# log step
log_step = 50

# %% [markdown]
# # Step 01. Download CelebA Dataset

# %%
celeb_transform = transforms.Compose([
                               transforms.Resize(image_size),
                               transforms.CenterCrop(image_size),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ])

celeb_a = CelebA(dataset_path, transform=celeb_transform, download=True)
data_loader = DataLoader(dataset=celeb_a, batch_size=batch_size, shuffle=True, **kwargs)
# Out:
# Files already downloaded and verified

# %%
# see training examples

real_batch = next(iter(data_loader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Image examples")
plt.imshow(np.transpose(make_grid(real_batch[0][:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %% [markdown]
# # Step 02. Define Model

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
# Simple Convs Generator

class Generator(nn.Module):
    
    def __init__(self, input_dim, output_dim):
        super(Generator, self).__init__()        
        
        self.convs = nn.Sequential(
        
            # project
            nn.ConvTranspose2d(input_dim, 512, kernel_size=(4, 4), stride=1, padding=0, bias=False),
            nn.ReLU(),
            
            # conv1
            nn.ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=2, padding=1, bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            
            # conv2
            nn.ConvTranspose2d(256, 64, kernel_size=(4, 4), stride=2, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            
            # conv3
            nn.ConvTranspose2d(64, 64, kernel_size=(4, 4), stride=2, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            
            # conv4
            nn.ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=2, padding=1, bias=False),
            nn.Tanh()
        )
        
        
    def forward(self, x):
        y_ = x
        return self.convs(y_)

# %%
G = Generator(input_dim=noise_dim, output_dim=sample_dim).to(DEVICE)
G.apply(weights_init)
# Out:
# Generator(
#   (convs): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): ReLU()
#     (2): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU()
#     (5): ConvTranspose2d(256, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): ConvTranspose2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (12): Tanh()
#   )
# )

# %%
class Discriminator(nn.Module):
    
    def __init__(self, input_dim, output_dim):
        super(Discriminator, self).__init__()
        
        self.convs = nn.Sequential(
        
            # (B, 64, 64, 3) ==> (B, 32, 32, 64)
            nn.Conv2d(input_dim, 512, kernel_size=(4, 4), stride=2, padding=1, bias=False),
            nn.LeakyReLU(0.2),
            
            # (B, 32, 32, 64) ==> (B, 16, 16, 128)
            nn.Conv2d(512, 256, kernel_size=(4, 4), stride=2, padding=1, bias=False),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),
            
            ## (B, 16, 16, 128) ==> (B, 8, 8, 256)
            nn.Conv2d(256, 128, kernel_size=(4, 4), stride=2, padding=1, bias=False),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),
            
            # (B, 8, 8, 256) ==> (B, 4, 4, 512)
            nn.Conv2d(128, 64, kernel_size=(4, 4), stride=2, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),
            
            # (B, 4, 4, 512) ==> (B, 1, 1, 1)
            nn.Conv2d(64, output_dim, kernel_size=(4, 4), stride=1, padding=0, bias=False),
            nn.Sigmoid(),
        )
        

    def forward(self, x):
        y_ = x
        return self.convs(y_).view(-1)

# %%
D = Discriminator(input_dim=sample_dim, output_dim=1).to(DEVICE)
D.apply(weights_init)
# Out:
# Discriminator(
#   (convs): Sequential(
#     (0): Conv2d(3, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): ReLU()
#     (2): Conv2d(512, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU()
#     (5): Conv2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): Conv2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (12): Sigmoid()
#   )
# )

# %% [markdown]
# # Step 03. Define Loss function and optimizer

# %%
criterion = nn.BCELoss()

D_optim = torch.optim.Adam(D.parameters(), lr=disc_lr, betas=(0.5, 0.999))
G_optim = torch.optim.Adam(G.parameters(), lr=gen_lr, betas=(0.5, 0.999))

# %% [markdown]
# # Step 04. Train Deep Convolutional GAN

# %%
def train_D(D, G, x, noise, D_labels, D_fakes):
    
    x_fake = G(noise)
    y_hat = D(x)
    y_hat_fake = D(x_fake.detach())
    
    return criterion(y_hat, D_labels) + criterion(y_hat_fake, D_fakes), (y_hat.mean(), y_hat_fake.mean())

def train_G(D, G, D_labels, noise):
    y_hat = D(G(noise))
    return criterion(y_hat, D_labels), y_hat.mean()

# %%
print("Start training Deep Convolutional GAN...")

for epoch in range(epochs):
    
    for step, (x, _) in enumerate(data_loader):
        d_batch_size = x.shape[0]
        
        D_labels = torch.ones((d_batch_size)).to(DEVICE) #  Discriminator Label to real
        D_fakes = torch.zeros((d_batch_size)).to(DEVICE) # Discriminator Label to fake
        x = x.view(d_batch_size, sample_dim, image_size, image_size).to(DEVICE)
        noise = torch.randn((d_batch_size, noise_dim, 1, 1)).to(DEVICE)
        
        # Train Discriminator
        G.eval()
        D.train()
        
        for _ in range(discriminator_train_step):
            D_optim.zero_grad()
            D_loss, D_accs = train_D(D, G, x, noise, D_labels, D_fakes)
            D_loss.backward()
            D_optim.step()
        
        
        # Train Generator
        G.train()
        D.eval()
        
        for _ in range(generator_train_step):
            G_optim.zero_grad()
            G_loss, G_acc = train_G(D, G, D_labels, noise)
            G_loss.backward()
            G_optim.step()
        
        if step % log_step == 0:
            print("\t[{}/{}]".format(epoch+1, epochs), \
                  "[{}/{}]".format(step, len(data_loader)), \
                  "   Gen.Loss",  "%.4f"%G_loss.item(), \
                  "   Disc.Loss: ", "%.4f"%D_loss.item(), \
                  "   D(x):", "%.2f"%D_accs[0].item(),\
                  "   D((G(z))): ", "Gen.", "%.2f"%G_loss.item(), " / Disc.", "%.2f"%D_accs[1].item()\
                 )
            
        step += 1
        
print("Finish!!")
# Out:
# Start training Deep Convolutional GAN...
# /home/minsu/anaconda3/envs/GAN_tutorial/lib/python3.7/site-packages/torch/nn/modules/loss.py:529: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([256])) is deprecated. Please ensure they have the same size.
#   return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-0fc64f9ab0b9> in <module>
#      17         for _ in range(discriminator_train_step):
#      18             D_optim.zero_grad()
# ---> 19             D_loss, D_accs = train_D(D, G, x, noise, D_labels, D_fakes)
#      20             D_loss.backward()
#      21             D_optim.step()
#
# <ipython-input-11-7e7a8b8f857f> in train_D(D, G, x, noise, D_labels, D_fakes)
#       5     y_hat_fake = D(x_fake.detach())
#       6
# ----> 7     return criterion(y_hat, D_labels) + criterion(y_hat_fake, D_fakes), (y_hat.mean(), y_hat_fake.mean())
#       8
#       9 def train_G(D, G, D_labels, noise):
#
# ~/anaconda3/envs/GAN_tutorial/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/GAN_tutorial/lib/python3.7/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     527
#     528     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 529         return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
#     530
#     531
#
# ~/anaconda3/envs/GAN_tutorial/lib/python3.7/site-packages/torch/nn/functional.py in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    2475     if input.numel() != target.numel():
#    2476         raise ValueError("Target and input must have the same number of elements. target nelement ({}) "
# -> 2477                          "!= input nelement ({})".format(target.numel(), input.numel()))
#    2478
#    2479     if weight is not None:
#
# ValueError: Target and input must have the same number of elements. target nelement (64) != input nelement (256)

# %% [markdown]
# # Step 05. Generate image samples

# %%
def get_sample_image(G, noise_dim=100):
    """
        save sample 100 images
    """
    z = torch.randn(test_batch_size, noise_dim, 1, 1).to(DEVICE)
    x_hat = G(z).view(test_batch_size, sample_dim, image_size, image_size)
    result = x_hat.cpu().data
    plt.figure(figsize=(8,8))
    plt.axis("off")
    plt.title("Image examples")
    plt.imshow(np.transpose(make_grid(result, padding=2, normalize=True), (1, 2, 0)))

# %%
G.eval()
get_sample_image(G, noise_dim=noise_dim)
